# %%
import numpy as np
import plotly.graph_objects as go
import ipywidgets as widgets
from IPython.display import display, clear_output

# --- CDS Pricing Functions ---
def calculate_cds_values(notional, spread_bps, term_years, recovery_rate, interest_rate):
    hazard_rates = np.linspace(0.01, 0.20, 1000)
    spread = spread_bps / 10000  # Convert bps to decimal
    r = interest_rate
    R = recovery_rate
    t = term_years
    N = notional * 1_000_000  # Convert millions to absolute dollars

    premiums, protections, npvs = [], [], []

    for h in hazard_rates:
        discount_factors = np.exp(-r * np.arange(1, t + 1))
        survival_probs = np.exp(-h * np.arange(1, t + 1))

        premium_leg = N * spread * np.sum(discount_factors * survival_probs)
        protection_leg = N * (1 - R) * np.sum(
            h * np.exp(-h * np.arange(1, t + 1)) * discount_factors
        )

        npv = protection_leg - premium_leg

        premiums.append(premium_leg)
        protections.append(protection_leg)
        npvs.append(npv)

    return hazard_rates * 100, premiums, protections, npvs

def find_breakeven_hazard_rate(hazard_rates, npvs):
    npvs = np.array(npvs)
    signs = np.sign(npvs)
    sign_changes = np.where(np.diff(signs))[0]
    if len(sign_changes) == 0:
        return None
    i = sign_changes[0]
    # Linear interpolation for better accuracy
    x0, x1 = hazard_rates[i], hazard_rates[i+1]
    y0, y1 = npvs[i], npvs[i+1]
    if y1 != y0:
        breakeven = x0 - y0 * (x1 - x0) / (y1 - y0)
        return breakeven
    else:
        return x0

# --- UI Elements ---
style = {'description_width': '250px'}
layout = widgets.Layout(width='800px')

notional_input = widgets.FloatText(value=10, description="Notional ($ millions):", style=style, layout=layout)
spread_input = widgets.FloatText(value=150, description="Spread (bps):", style=style, layout=layout)
term_input = widgets.IntText(value=5, description="Term (years):", style=style, layout=layout)
recovery_input = widgets.FloatText(value=40, description="Recovery Rate (%):", style=style, layout=layout)
interest_input = widgets.FloatText(value=3, description="Interest Rate (%):", style=style, layout=layout)
update_button = widgets.Button(description="Update Graph")

output = widgets.Output()

# --- Plotting Function ---
def update_graph(_):
    with output:
        clear_output()

        notional = notional_input.value
        spread = spread_input.value
        term = term_input.value
        recovery_rate = recovery_input.value / 100  # Convert % to decimal
        interest_rate = interest_input.value / 100  # Convert % to decimal

        hazard_rates, premiums, protections, npvs = calculate_cds_values(
            notional, spread, term, recovery_rate, interest_rate
        )

        breakeven = find_breakeven_hazard_rate(hazard_rates, npvs)

        fig = go.Figure()

        # Shaded region for Profit
        fig.add_trace(go.Scatter(
            x=hazard_rates,
            y=[max(n, 0) for n in npvs],
            fill='tozeroy',
            mode='none',
            fillcolor='rgba(0, 200, 0, 0.1)',
            name='Positive NPV',
            hoverinfo='skip'
        ))

        # Shaded region for Loss
        fig.add_trace(go.Scatter(
            x=hazard_rates,
            y=[min(n, 0) for n in npvs],
            fill='tozeroy',
            mode='none',
            fillcolor='rgba(200, 0, 0, 0.1)',
            name='Negative NPV',
            hoverinfo='skip'
        ))

        fig.add_trace(go.Scatter(
            x=hazard_rates,
            y=premiums,
            mode='lines',
            name='Premium Leg PV',
            hovertemplate='Premium Leg PV: $%{y:,.2f}<extra></extra>'
        ))

        fig.add_trace(go.Scatter(
            x=hazard_rates,
            y=protections,
            mode='lines',
            name='Protection Leg PV',
            hovertemplate='Protection Leg PV: $%{y:,.2f}<extra></extra>'
        ))

        fig.add_trace(go.Scatter(
            x=hazard_rates,
            y=npvs,
            mode='lines',
            name='Net Present Value',
            hovertemplate='Net Present Value: $%{y:,.2f}<extra></extra>'
        ))

        if breakeven is not None:
            fig.add_trace(go.Scatter(
                x=[breakeven],
                y=[0],
                mode='markers+text',
                marker=dict(color='black', size=10),
                text=[f'Breakeven: {breakeven:.2f}%'],
                textposition='top right',
                name='Breakeven Point',
                hovertemplate='Breakeven Hazard Rate: %{x:.2f}%<extra></extra>'
            ))

        fig.update_layout(
            title='CDS Valuation vs Hazard Rate',
            xaxis=dict(
                title='Hazard Rate (%)',
                showgrid=True,
                gridwidth=1,
                gridcolor='LightGray',
                zeroline=False,
                showline=True,
                linewidth=1,
                linecolor='Black',
                minor=dict(
                    showgrid=True,
                    gridwidth=0.5,
                    gridcolor='LightGray',
                ),
                dtick=1,
                minor_ticks='outside'
            ),
            yaxis=dict(
                title='Value ($)',
                showgrid=True,
                gridwidth=1,
                gridcolor='LightGray',
                zeroline=False,
                showline=True,
                linewidth=1,
                linecolor='Black',
                minor=dict(
                    showgrid=True,
                    gridwidth=0.5,
                    gridcolor='LightGray',
                ),
                minor_ticks='outside',
            ),
            hovermode='x unified',
            height=600
        )

        display(fig)

update_button.on_click(update_graph)

# --- Display UI ---
display(notional_input, spread_input, term_input, recovery_input, interest_input, update_button, output)

# Run once at start
update_graph(None)
# Out:
# FloatText(value=10.0, description='Notional ($ millions):', layout=Layout(width='800px'), style=DescriptionSty…
# FloatText(value=150.0, description='Spread (bps):', layout=Layout(width='800px'), style=DescriptionStyle(descr…
# IntText(value=5, description='Term (years):', layout=Layout(width='800px'), style=DescriptionStyle(description…
# FloatText(value=40.0, description='Recovery Rate (%):', layout=Layout(width='800px'), style=DescriptionStyle(d…
# FloatText(value=3.0, description='Interest Rate (%):', layout=Layout(width='800px'), style=DescriptionStyle(de…
# Button(description='Update Graph', style=ButtonStyle())
# Output()

# %%
import pandas as pd
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
url = "https://raw.githubusercontent.com/datasets/finance-vix/main/data/vix-daily.csv"
df = pd.read_csv(url)

df.head()


plt.figure(figsize=(16,6))
plt.plot(df['DATE'], df['CLOSE'], label='VIX')

# Format the x-axis
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval = 5))   # Major ticks every month

plt.xticks(rotation=45)
plt.title('VIX Index Over Time')
plt.xlabel('Date')
plt.ylabel('Close')
plt.legend()
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import plotly.graph_objects as go
url = "https://raw.githubusercontent.com/datasets/finance-vix/main/data/vix-daily.csv"
df = pd.read_csv(url)
df['DATE'] = pd.to_datetime(df['DATE'])
df_monthly = df.resample('ME', on='DATE').mean().reset_index()

# df.head()

fig = go.Figure()

fig.add_trace(go.Scatter(
    x=df_monthly['DATE'],
    y=df_monthly['CLOSE'],
    mode='lines+markers',
    name='VIX Close',
    line=dict(color='blue'),
    hovertemplate='Date: %{x|%b %Y}<br>Close: %{y:.2f}<extra></extra>'
))

# Layout
fig.update_layout(
    title='VIX Index Over Time',
    xaxis_title='Date',
    yaxis_title='VIX Close',
    hovermode='x unified',
    template='plotly_white',
    height=600
)

fig.show()

# %%
import pandas as pd
import yfinance as yf
import plotly.express as px

data = yf.download("LQD", start="2020-01-01", end="2025-01-01")
print(data.head())
print(data.columns)
# Out:
# C:\Users\jamie\AppData\Local\Temp\ipykernel_11672\2794173895.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("LQD", start="2020-01-01", end="2025-01-01")
# [*********************100%***********************]  1 of 1 completed
# Price            Close        High         Low        Open    Volume
# Ticker             LQD         LQD         LQD         LQD       LQD
# Date
# 2020-01-02  104.914665  105.192854  104.775577  105.004665  15348700
# 2020-01-03  105.274719  105.307453  104.947454  105.053808  10110900
# 2020-01-06  104.922874  105.430139  104.841052  105.291051  13894300
# 2020-01-07  104.652908  104.873807  104.595630  104.865630   8211700
# 2020-01-08  104.505608  104.988335  104.456513  104.734690  12268500
# MultiIndex([( 'Close', 'LQD'),
#             (  'High', 'LQD'),
#             (   'Low', 'LQD'),
#             (  'Open', 'LQD'),
#             ('Volume', 'LQD')],
#            names=['Price', 'Ticker'])

# %%
import pandas as pd

df = pd.read_csv("CDX_index_hist.csv")
print(df.head())
df.describe()
df.info()
# Out:
#          Date  Close/Last  Volume   Open     High    Low
# 0  10/24/2025       22.85  160416  22.82  22.9299  22.77
# 1  10/23/2025       22.88  259797  22.88  22.8800  22.77
# 2  10/22/2025       22.87  273403  22.90  22.9100  22.76
# 3  10/21/2025       22.84  235125  22.81  22.8800  22.80
# 4  10/20/2025       22.82   87577  22.89  22.8900  22.78
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        204 non-null    object
#  1   Close/Last  204 non-null    float64
#  2   Volume      204 non-null    int64
#  3   Open        204 non-null    float64
#  4   High        204 non-null    float64
#  5   Low         204 non-null    float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 9.7+ KB

# %%
import plotly.express as px

cdx = pd.read_csv("CDX_index_hist.csv")
cdx["Date"] = pd.to_datetime(cdx["Date"])
cdx = cdx.sort_values("Date")

fig = px.line(cdx, x="Date", y="Close/Last", title="CDX Index Price over Time")
fig2 = px.line(cdx, x="Date", y="Volume", title="Volume over time")
fig.show()
fig2.show()

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import ipywidgets as widgets
from IPython.display import display, clear_output

# --- CDS NPV Calculation for a single hazard rate ---
def calculate_cds_values_single_hazard(notional, spread_bps, term_years, recovery_rate, interest_rate, hazard_rate):
    """
    Calculate premium leg, protection leg, and NPV for a CDS given a single hazard rate.
    """
    spread = spread_bps / 10000         # Convert bps to decimal
    r = interest_rate                   # discount rate as decimal
    R = recovery_rate                   # recovery rate as decimal
    t = term_years
    N = notional * 1_000_000            # Converts millions to absolute dollars

    payment_times = np.arange(1, t + 1)
    discount_factors = np.exp(-r * payment_times)
    survival_probs = np.exp(-hazard_rate * payment_times)
    prev_survival_probs = np.insert(survival_probs[:-1], 0, 1.0)

    premium_leg = N * spread * np.sum(discount_factors * survival_probs)
    protection_leg = N * (1 - R) * np.sum(discount_factors * (prev_survival_probs - survival_probs))
    npv = protection_leg - premium_leg

    return premium_leg, protection_leg, npv


cdx = pd.read_csv("CDX_index_hist.csv") 
recovery_rate = 0.4                       

# Computes implied hazard rates from CDX close price
cdx['HazardRate'] = (cdx['Close/Last'] / 10000) / (1 - recovery_rate)
cdx['ImpliedSpreadBps'] = cdx['HazardRate'] * (1 - recovery_rate) * 10000

# --- Computes NPV for each row ---
npvs = []
for idx, row in cdx.iterrows():
    _, _, npv = calculate_cds_values_single_hazard(
        notional=10,                 
        spread_bps=row['ImpliedSpreadBps'],  
        term_years=5,
        recovery_rate=recovery_rate,
        interest_rate=0.03,          
        hazard_rate=row['HazardRate']
    )
    npvs.append(npv)

cdx['NPV'] = npvs

initial_npv = cdx['NPV'].iloc[0]

# --- Plotting ---
fig = go.Figure()

cdx['Date'] = pd.to_datetime(cdx['Date'], format='%m/%d/%Y')
cdx = cdx.sort_values('Date')


# NPV line
fig.add_trace(go.Scatter(
    x=cdx['Date'],
    y=cdx['NPV'],
    mode='lines',
    name='CDS NPV'
))

# Breakeven line 
fig.add_trace(go.Scatter(
    x=cdx['Date'],
    y=[initial_npv]*len(cdx),
    mode='lines',
    name='Breakeven',
    line=dict(color='black', dash='dash')
))

fig.update_layout(
    title='CDS NPV vs Time (CDX-Implied Hazard Rates)',
    xaxis_title='Date',
    yaxis_title='NPV ($)',
    hovermode='x unified',
    height=600
)
# Shaded regions for P/L
fig.add_trace(go.Scatter(
    x=cdx['Date'],
    y=[max(n - initial_npv, 0) + initial_npv for n in cdx['NPV']],
    fill='tonexty',
    mode='none',
    fillcolor='rgba(0, 200, 0, 0.4)',
    name='Profit'
))

fig.add_trace(go.Scatter(
    x=cdx['Date'],
    y=[min(n - initial_npv, 0) + initial_npv for n in cdx['NPV']],
    fill='tonexty',
    mode='none',
    fillcolor='rgba(200, 0, 0, 0.2)',
    name='Loss'
))

fig.show()
